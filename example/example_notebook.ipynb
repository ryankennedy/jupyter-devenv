# %% [markdown]
# # Example Notebook
#
# This is an example notebook, included in the Docker image.

# %%
# %matplotlib inline

import pandas as pd

# %%
pd.read_csv('https://openei.org/doe-opendata/dataset/9720c474-5f8a-4c14-b667-ce3cdb484fcb/resource/96ce9a9c-65dd-48c6-a540-1fd56ab0ff47/download/openeiutilitycompanyinfo.csv')
# Out:
#                                Utility Company EIA Utility Id  \
# 0                     3 Phases Energy Services          21093
# 1                 4-County Electric Power Assn           6641
# 2               A & N Electric Coop (Virginia)             84
# 3                       AEP Generating Company            343
# 4                                     AEP Ohio           4062
# 5                    AEP Texas Central Company           3278
# 6                      AEP Texas North Company          20404
# 7                        AES Eastern Energy LP            134
# 8                      AGC Division of APG Inc            261
# 9                              AP Holdings LLC          56571
# 10                  AP Holdings LLC (New York)          56571
# 11                         APN Starfirst, L.P.          50153
# 12              APN Starfirst, L.P. (Illinois)          50153
# 13                  APN Starfirst, L.P. (Ohio)          50153
# ...
